# %%
from model_helpers import *

# %load_ext autoreload
# %autoreload 2

os.environ['CUDA_VISIBLE_DEVICES'] = '0'
# Out:
# /software/anaconda3/5.2/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = create_anomaly_cnn()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 128, 128, 3)       0
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 130, 130, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 126, 126, 32)      2432
# _________________________________________________________________
# elu_1 (ELU)                  (None, 126, 126, 32)      0
# _________________________________________________________________
# lambda_2 (Lambda)            (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 126, 126, 64)      18496
# _________________________________________________________________
# elu_2 (ELU)                  (None, 126, 126, 64)      0
# ...
